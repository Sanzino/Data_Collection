# %% [markdown]
# # SpaceX Launch Data Analysis - Practice Exercise
# Extracting, cleaning, merging, and analyzing SpaceX launch data from the public API.

# %% [markdown]
# ## Part 1: Data Acquisition (10 Marks)
#
# - Fetch data from both endpoints using `requests`:
#   1. Launches: `https://api.spacexdata.com/v4/launches`
#   2. Rockets: `https://api.spacexdata.com/v4/rockets`
# - Verify HTTP status codes
# - Parse JSON responses into Python lists/dictionaries

# %%
# Your code here

# %% [markdown]
# ## Part 2: DataFrame Creation & Cleaning (10 Marks)
#
# ### df_launches
# - Extract keys: `id`, `name`, `date_utc`, `rocket`, `success`, `upcoming`, `failures`
# - Rename columns to: `launch_id`, `mission_name`, `date_utc`, `rocket_id`, `success`, `upcoming`, `failures`
# - Filter out upcoming launches (`upcoming == True`)
# - Convert `date_utc` to datetime
# - Create `launch_year` column
#
# ### df_rockets
# - Extract keys: `id`, `name`, `company`, `cost_per_launch`, `success_rate_pct`
# - Rename columns to: `rocket_id`, `rocket_name`, `cost_per_launch`, `expected_success_rate_pct`

# %%
# df_launches

# %%
# df_rockets

# %% [markdown]
# ## Part 3: Data Transformation & Merging (10 Marks)
#
# - Merge `df_launches` and `df_rockets` using a **left join** on rocket ID → `df_merged`
# - Create `failure_reason` column (extract text reason from failures list, or `"None"` if no failure)
# - Drop redundant columns (`upcoming`, raw `failures`, `rocket_id`)

# %%
# Your code here

# %% [markdown]
# ## Part 4: Insights from the Data (20 Marks)
#
# Answer each question in its own cell below.

# %% [markdown]
# ### 4.1 How many total launches per year? Which year had the most?

# %% [markdown]
# ### 4.2 Actual success rate per rocket type (calculated dynamically, not from API field)

# %% [markdown]
# ### 4.3 Estimated total cost of all *failed* launches combined

# %% [markdown]
# ### 4.4 Most common failure_reason across all failed missions

# %% [markdown]
# ### 4.5 Success rate per month (1-12) — which is SpaceX's "luckiest" month?

# %% [markdown]
# ### 4.6 Categorize launches by time of day (Night 0-5, Morning 6-11, Afternoon 12-17, Evening 18-23) — which has highest volume?

# %% [markdown]
# ### 4.7 Longest streak of consecutive successful launches
# *Hint: sort by date, use cumulative sums to identify continuous blocks of `True` in `success`*

# %% [markdown]
# ### 4.8 Total money spent on launches per year

# %% [markdown]
# ### 4.9 Stacked bar chart: successful vs failed launches per rocket_name
# Include title, axis labels, and legend.

# %% [markdown]
# ### 4.10 Line graph: cumulative number of launches over time
